# %%
import numpy as np
import pandas as pd

# %%
df_op_p = pd.read_csv('order_products__prior.csv')

# %%
df_orders = pd.read_csv('orders.csv')
df_a = pd.read_csv('aisles.csv')
df_p = pd.read_csv('products.csv')
df_d = pd.read_csv('departments.csv')
df_op_t = pd.read_csv('order_products__train.csv')

# %%
df_op_p.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
df_op_p[df_op_p.order_id == 2539329]
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 24076664   2539329         196                  1          0
# 24076665   2539329       14084                  2          0
# 24076666   2539329       12427                  3          0
# 24076667   2539329       26088                  4          0
# 24076668   2539329       26405                  5          0

# %%
len(df_orders)
# Out:
# 3421083

# %%
df_op_p.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 0          2       33120                  1          1
# 1          2       28985                  2          1
# 2          2        9327                  3          0
# 3          2       45918                  4          1
# 4          2       30035                  5          0
# 5          2       17794                  6          1
# 6          2       40141                  7          1
# 7          2        1819                  8          1
# 8          2       43668                  9          0
# 9          3       33754                  1          1
# 10         3       24838                  2          1
# 11         3       17704                  3          1
# 12         3       21903                  4          1
# 13         3       17668                  5          1
# 14         3       46667                  6          1
# 15         3       17461                  7          1
# ...

# %%
df_op_t.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 0          1       49302                  1          1
# 1          1       11109                  2          1
# 2          1       10246                  3          0
# 3          1       49683                  4          0
# 4          1       43633                  5          1
# 5          1       13176                  6          0
# 6          1       47209                  7          0
# 7          1       22035                  8          1
# 8         36       39612                  1          0
# 9         36       19660                  2          1
# 10        36       49235                  3          0
# 11        36       43086                  4          1
# 12        36       46620                  5          1
# 13        36       34497                  6          1
# 14        36       48679                  7          1
# 15        36       46979                  8          1
# ...

# %%
df_orders[df_orders.user_id == 112108]
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 1868041   1427983   112108    prior             1          1
# 1868042   2541372   112108    prior             2          1
# 1868043    186706   112108    prior             3          2
# 1868044         1   112108    train             4          4
#
#          order_hour_of_day  days_since_prior_order
# 1868041                 14                     NaN
# 1868042                 10                     7.0
# 1868043                 21                    15.0
# 1868044                 10                     9.0
